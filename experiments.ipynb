# %% [markdown]
# # Day 1
# * Trying out the code https://www.kaggle.com/rdokov/background-removal/code [on hold]
# * steps
#     1. display .png in python

# %%
#import Image #works upto python3.2
import PIL
from PIL import Image

# %%
def display(img_path):
    """
    INPUT
    img: filename of the image file (eg. gig.png, 2.png etc.)
    
    OUTPUT
    The image is displayed
    """
    return Image.open(img_path)

# %%
Image.open?

# %%
display("./train/101.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=540x420 at 0x7F845C52AB38>
